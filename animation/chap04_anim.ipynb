# %% [markdown]
# # 推測統計の基本

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as ani
from IPython.display import HTML

# %precision 3
# %matplotlib inline

# %%
df = pd.read_csv('../data/ch4_scores400.csv')
scores = np.array(df['点数'])

dice = [1, 2, 3, 4, 5, 6]
prob = [1/21, 2/21, 3/21, 4/21, 5/21, 6/21]

# %% [markdown]
# ## 図4.3 試行回数を変化させたときの出目のヒストグラム

# %%
num_frame = 50
space = np.logspace(2, 5, num_frame).astype(int)
sample = np.random.choice(dice, size=100000, p=prob)

def animate(nframe):
    num_trial = space[nframe]
    ax.clear()
    ax.hist(sample[:num_trial], bins=6, range=(1, 7), density=True, rwidth=0.8)
    ax.hlines(prob, np.arange(1, 7), np.arange(2, 8), colors='gray')
    ax.set_title(f'試行回数:{num_trial}')
    ax.set_xticks(np.linspace(1.5, 6.5, 6))
    ax.set_xticklabels(np.arange(1, 7))
    ax.set_ylim(0, 0.3)
    ax.set_xlabel('出目', fontsize=12)
    ax.set_ylabel('相対度数', fontsize=12)
    
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
anim = ani.FuncAnimation(fig, animate, frames=num_frame)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img82d7785f56f9414b83b4233753bd81ba">
#     <br>
#     <input id="_anim_slider82d7785f56f9414b83b4233753bd81ba" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim82d7785f56f9414b83b4233753bd81ba.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim82d7785f56f9414b83b4233753bd81ba.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim82d7785f56f9414b83b4233753bd81ba.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim82d7785f56f9414b83b4233753bd81ba.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim82d7785f56f9414b83b4233753bd81ba.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim82d7785f56f9414b83b4233753bd81ba.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim82d7785f56f9414b83b4233753bd81ba.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim82d7785f56f9414b83b4233753bd81ba.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim82d7785f56f9414b83b4233753bd81ba.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim82d7785f56f9414b83b4233753bd81ba.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select82d7785f56f9414b83b4233753bd81ba" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img82d7785f56f9414b83b4233753bd81ba";
#     var slider_id = "_anim_slider82d7785f56f9414b83b4233753bd81ba";
#     var loop_select_id = "_anim_loop_select82d7785f56f9414b83b4233753bd81ba";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3Xt01OWB//HPcAsSakSDQASS1Aib\
# NNySCZngWCeNgjZaSNesLAclAkmha7FWe1ZYZdk9q6VHoawXkDGrWUTFS0CstAqyJhBl0IRgkGB3\
# Ewm3EMJlMzbUjOLO74/+mENMlDw45JuZeb/O4ZiZ7/Od+XwfBvn4+MyMze/3+wUAAACgS3pZHQAA\
# AAAIJRRoAAAAwAAFGgAAADBAgQYAAAAMUKABAAAAAxRoAAAAwAAFGgAAADBAgQYAAAAMUKABAAAA\
# AxRoAAAAwAAFGgAAADBAgQYAAAAMUKABAAAAAxRoAAAAwAAFGgAAADBAgQYAAAAMUKABAAAAAxRo\
# AAAAwAAFGgAAADBAgQYAAAAMUKABAAAAAxRoAAAAwAAFGgAAADBAgQYAAAAMUKABAAAAAxRoAAAA\
# wAAFGgAAADBAgQYAAAAMUKABAAAAAxRoAAAAwAAFGgAAADBAgQYAAAAMUKABAAAAAxRoAAAAwAAF\
# GgAAADBAgQaAIMvIyNCBAwf0/vvvB+47c+aM1q9ff1Ge7+WXX9aBAwfkcDjk9Xr16KOPSpJmzZql\
# AwcOdPlxPv74Y2VlZWnFihXt7n/wwQd1xRVXKCsrS8ePH5ck+f1+3XXXXRo0aJByc3PV1tYWvAsC\
# gB6OAg0AF+BnP/uZHA6HHA6HNm3a1O6YzWbToUOHtGDBAvn9fknSr3/9a+3Zs0eSdN1112n8+PHt\
# fj388MOB810ul1JSUjqMOfsrJSVFLpcrMP6rr77S6tWrJUnr1q3T0KFDJUm7du1Snz591NTUpKam\
# Jvl8vm+9pmXLlik6OrrdfdXV1Vq/fr2OHDmitLS0QM6NGzfq8OHDam5uVq9evfT0009fwCwCQGjq\
# Y3UAAAg1dXV1GjFihEaMGCFJKisr0+9+97vA8f/+7//WggULVFdXpzfeeENbt27VyZMntXTpUknS\
# 9u3bz/scb7zxhpKSkr7x+efOnSvprwX3qaeeks1mU21trZ5//nlJUnx8vI4fP645c+aovr5e0dHR\
# WrVqlbKysr7xOZ977jktWbKk3X1btmzRbbfdpv79+8tms2nLli2SpM2bN+vv//7v1bdvX/n9fm3Z\
# skW//OUvz3tdABAOWIEGAENJSUkaMmSI2tra1NbWpunTp+v1118P/Jo4caL++Mc/6rPPPlNWVpaG\
# DRum559/XjfffLN27tzZ5edZsWKFxo4dK7vdLrvdrjFjxmjVqlXtxkyYMEHvvfeeJk6cqL59+yo3\
# N1dbtmxRY2OjZsyYobfeeku33HKLHn/88Xbl2eVyqaCg4LwZDhw4oKuvvlqNjY0aO3asjh492u7+\
# Dz74QFOnTjXaKgIAoY4CDQAXYOzYsXI6nXI6nRo6dKhOnToV2Cpx+eWX69ixY5KkK6+8UgsXLlRx\
# cbGuuuoqvf/+++22YwwePFiJiYkaP368Kisr2z1HS0uLFi1apMrKSlVWVuq+++6T1+ttN6a5uVn5\
# +flKTk7WNddco7/5m7/R7bffrrVr16q2tlaS9Mknn2jUqFHtzhs5cqSGDRt23uv8/PPPNXDgQK1f\
# v14zZ87U//3f/7W7v6ysTHl5efr8888veC4BINSwhQMALsCzzz6rjz76SJL00EMP6b/+67/04osv\
# 6tprr9WAAQPU1NSksWPHSpLKy8v1q1/9Sk8++aQKCgp07733Bh7nl7/8pVwul6ZNm3ZBOc6cOaPZ\
# s2frBz/4gdatW6e8vDxNmTJF06dPl8/n06lTp3To0KHAvuiz1qxZ06XHv+SSS+Tz+dSrVy8NGDAg\
# sKf7kksu0YkTJzRs2DD95S9/0SWXXHJB+QEgFFGgAeACnH3T3lm5ubnau3evSkpK9

# %% [markdown]
# ## 図4.5 無作為抽出で得た標本データのヒストグラム

# %%
np.random.seed(0)
sample = np.random.choice(scores, 10000)
num_frame = 50
space = np.logspace(1, 4, num_frame).astype(int)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
def animate(nframe):
    num_sample = space[nframe]
    ax.clear()
    ax.hist(sample[:num_sample], bins=100, range=(0, 100), density=True)
    ax.set_xlabel('点数', fontsize=12)
    ax.set_ylabel('相対度数', fontsize=12)
    ax.set_title(f'サンプルサイズ：{num_sample}')
    ax.set_xlim(20, 100)
    
anim = ani.FuncAnimation(fig, animate, frames=num_frame)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img53ac80ca3aa340fcbf4bd8ea9d5ef355">
#     <br>
#     <input id="_anim_slider53ac80ca3aa340fcbf4bd8ea9d5ef355" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim53ac80ca3aa340fcbf4bd8ea9d5ef355.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim53ac80ca3aa340fcbf4bd8ea9d5ef355.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim53ac80ca3aa340fcbf4bd8ea9d5ef355.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim53ac80ca3aa340fcbf4bd8ea9d5ef355.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim53ac80ca3aa340fcbf4bd8ea9d5ef355.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim53ac80ca3aa340fcbf4bd8ea9d5ef355.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim53ac80ca3aa340fcbf4bd8ea9d5ef355.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim53ac80ca3aa340fcbf4bd8ea9d5ef355.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim53ac80ca3aa340fcbf4bd8ea9d5ef355.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim53ac80ca3aa340fcbf4bd8ea9d5ef355.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select53ac80ca3aa340fcbf4bd8ea9d5ef355" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img53ac80ca3aa340fcbf4bd8ea9d5ef355";
#     var slider_id = "_anim_slider53ac80ca3aa340fcbf4bd8ea9d5ef355";
#     var loop_select_id = "_anim_loop_select53ac80ca3aa340fcbf4bd8ea9d5ef355";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X10lOWd//HPEEjiBojIIAQEgsQg\
# GAh5IpN21MQcwa4PMN1SEKkEkLQW68pZ2JW4UtZVYFu1rpVqRnZ9AAqICW1BBREIMUrQBDBo1AIS\
# RALmQTNIlgwPzu8PND8xk8CFZGYy836d02Mm93Xf851vrgmfc/XK3BaPx+MRAAAAgPPSyd8FAAAA\
# AB0JARoAAAAwQIAGAAAADBCgAQAAAAMEaAAAAMAAARoAAAAwQIAGAAAADBCgAQAAAAMEaAAAAMAA\
# ARoAAAAwQIAGAAAADBCgAQAAAAMEaAAAAMAAARoAAAAwQIAGAAAADBCgAQAAAAMEaAAAAMAAARoA\
# AAAwQIAGAAAADBCgAQAAAAMEaAAAAMAAARoAAAAwQIAGAAAADBCgAQAAAAMEaAAAAMAAARoAAAAw\
# QIAGAAAADBCgAQAAAAMEaAAAAMAAARoAAAAwQIAGAAAADBCgAQAAAAMEaAAAAMAAARoAfOSNN97Q\
# bbfdpvLycn+XAgD4AQjQAOAjK1eulNPp1HPPPefvUuRyuYzPqa2t1erVqy/4OQ8cOKBbbrlF9913\
# 31nff/rpp9W7d29dc8012rNnzwVfHwB8hQANIOTMnj1bzzzzTPPjRYsW6eGHH/Y6dtu2bTp27NgF\
# P9fp06d14sQJHT9+XFarVW+++ab69et31ph33nlHTU1NOnLkiO64446LWr83y5Yt0w033KCvv/76\
# vOo/efKkiouLlZeXp6efflpbtmw57+f6rsWLF6tz585nfa+mpkYPP/ywKisrlZOTozlz5lzQtQHA\
# lwjQANCGp59+WvHx8dq4cWOLYydOnDjrcVVVlWJiYtSvXz9dccUV6t+/v6666ioNHz5cgwYN0tdf\
# f60+ffq0CIl33HGHampq1NTUpO3bt7fr63nttdeUl5enlStXqlOnlv8ETJ06VTExMerTp49iYmI0\
# cOBAxcTE6IUXXlBUVJQee+wxpaSkXNBz/+53v9O4cePO+l5RUZGys7PVs2dPud1ulZSUyOPxXND1\
# AcBXOp97CAAEh5ycHElSWVmZunXrptLSUknS7t275fF4tHfvXknSU089pa5du0qSXnzxRa1YsUKT\
# J0/WBx98IKvV2ny9OXPmKDMzUw6HQ5IUGxurw4cPt/rcffr00bXXXtvi2KlTp9SlSxe53e6LXv93\
# Pffcc8rLy9OWLVt01VVXeX0Ob9tLpk6dquHDh7fYevF9JSUlioiIUFpaWpvjvuvAgQMaPHiwmpqa\
# FB4erh49eqi+vv6sPgNAoCFAAwgZd911lyTJ7Xbriiuu0NixYyVJL7zwgjp37ty8fSIyMvKs826/\
# /XbdeuutZ4XSiooK/e1vf9Mjjzxyzuf9+uuv9eqrr7a6PaGxsVFdu3b1GqBPnz6tsLCwH1R/Q0OD\
# /vmf/1lbtmzR4MGDdfXVV5+z5m/t379f69ev15NPPnnOsf/+7/8uq9Wql19++byvf/z4cXXt2lWF\
# hYW6/fbbtXTpUh0/fvy8zwcAf2ALB4CQYbfbZbfb1a9fPw0ePLj5cY8ePTRixIjmx9/fpyvprPDc\
# 0NCgiRMnasGCBV5Xer9vxYoVGjBggK655poWx06dOqXjx4+rW7duLY793//9nzIzM/X5559fUP1N\
# TU367//+byUlJSkhIUHPP//8+bZKkuTxeDRz5kwtWrTIa33ft3r1ajmdTqPnuOSSS3T69GnV1dWp\
# f//+amxs1CWXXGJ0DQDwNQI0gJC3Z88eXXnllec1tqamRqNHj9bEiRN1++23n3N8fX29Zs2a1eof\
# +e3YsUNDhgzxemzq1Km64oor1Lt37zafo7X6165dq/fff1/FxcWaM2eO1z3PbfnP/

# %% [markdown]
# ## 図4.6 標本平均の分布

# %%
np.random.seed(0)
sample_means = [np.random.choice(scores, 20).mean() for _ in range(10000)]

num_frame = 50
space = np.logspace(1, 4, num_frame).astype(int)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

def animate(nframe):
    num_trial = space[nframe]
    ax.clear()
    prob, _, _ = ax.hist(sample_means[:num_trial],
                         bins=100, range=(0, 100), density=True)
    ax.vlines(np.mean(scores), 0, 1, 'gray')
    ax.set_title(f'試行回数：{num_trial}')
    ax.set_xlabel('点数', fontsize=12)
    ax.set_ylabel('相対度数', fontsize=12)
    ax.set_xlim(50, 90)
    ax.set_ylim(0, prob.max() * 1.1)
    
anim = ani.FuncAnimation(fig, animate, frames=num_frame)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgd56df79c01a549c98339da989ddd1b52">
#     <br>
#     <input id="_anim_sliderd56df79c01a549c98339da989ddd1b52" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animd56df79c01a549c98339da989ddd1b52.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animd56df79c01a549c98339da989ddd1b52.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animd56df79c01a549c98339da989ddd1b52.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animd56df79c01a549c98339da989ddd1b52.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animd56df79c01a549c98339da989ddd1b52.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animd56df79c01a549c98339da989ddd1b52.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animd56df79c01a549c98339da989ddd1b52.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animd56df79c01a549c98339da989ddd1b52.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animd56df79c01a549c98339da989ddd1b52.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animd56df79c01a549c98339da989ddd1b52.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectd56df79c01a549c98339da989ddd1b52" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd56df79c01a549c98339da989ddd1b52";
#     var slider_id = "_anim_sliderd56df79c01a549c98339da989ddd1b52";
#     var loop_select_id = "_anim_loop_selectd56df79c01a549c98339da989ddd1b52";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X