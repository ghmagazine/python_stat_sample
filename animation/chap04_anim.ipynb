# %% [markdown]
# # 推測統計の基本

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as ani
from IPython.display import HTML

# %precision 3
# %matplotlib inline

# %%
df = pd.read_csv('../data/ch4_scores400.csv')
scores = np.array(df['点数'])

dice = [1, 2, 3, 4, 5, 6]
prob = [1/21, 2/21, 3/21, 4/21, 5/21, 6/21]

# %% [markdown]
# ## 図4.3 試行回数を変化させたときの出目のヒストグラム

# %%
num_frame = 50
space = np.logspace(2, 5, num_frame).astype(int)
sample = np.random.choice(dice, size=100000, p=prob)

def animate(nframe):
    num_trial = space[nframe]
    ax.clear()
    ax.hist(sample[:num_trial], bins=6, range=(1, 7), density=True, rwidth=0.8)
    ax.hlines(prob, np.arange(1, 7), np.arange(2, 8), colors='gray')
    ax.set_title(f'試行回数:{num_trial}')
    ax.set_xticks(np.linspace(1.5, 6.5, 6))
    ax.set_xticklabels(np.arange(1, 7))
    ax.set_ylim(0, 0.3)
    ax.set_xlabel('出目', fontsize=12)
    ax.set_ylabel('相対度数', fontsize=12)
    
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
anim = ani.FuncAnimation(fig, animate, frames=num_frame)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img6fc69839c61841a2861ab18cf063c4fd">
#     <br>
#     <input id="_anim_slider6fc69839c61841a2861ab18cf063c4fd" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim6fc69839c61841a2861ab18cf063c4fd.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim6fc69839c61841a2861ab18cf063c4fd.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim6fc69839c61841a2861ab18cf063c4fd.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim6fc69839c61841a2861ab18cf063c4fd.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim6fc69839c61841a2861ab18cf063c4fd.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim6fc69839c61841a2861ab18cf063c4fd.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim6fc69839c61841a2861ab18cf063c4fd.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim6fc69839c61841a2861ab18cf063c4fd.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim6fc69839c61841a2861ab18cf063c4fd.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim6fc69839c61841a2861ab18cf063c4fd.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select6fc69839c61841a2861ab18cf063c4fd" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6fc69839c61841a2861ab18cf063c4fd";
#     var slider_id = "_anim_slider6fc69839c61841a2861ab18cf063c4fd";
#     var loop_select_id = "_anim_loop_select6fc69839c61841a2861ab18cf063c4fd";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X10lOWB/vFrCBAkYESDQARCagyb\
# NLwlEzLBsU4aBW20kK5ZWQ5KBJJC12Kt9mxhlbJ7VkuPQllfQMasZhEVXwJipVWQNYEogyYEgwZ3\
# NxF5CxAomzFJzSjs/P7ojzmNiZKbDnkyM9/PORwzz3M/M9dzw8HL23tmbH6/3y8AAAAA3dLH6gAA\
# AABAKKFAAwAAAAYo0AAAAIABCjQAAABggAINAAAAGKBAAwAAAAYo0AAAAIABCjQAAABggAINAAAA\
# GKBAAwAAAAYo0AAAAIABCjQAAABggAINAAAAGKBAAwAAAAYo0AAAAIABCjQAAABggAINAAAAGKBA\
# AwAAAAYo0AAAAIABCjQAAABggAINAAAAGKBAAwAAAAYo0AAAAIABCjQAAABggAINAAAAGKBAAwAA\
# AAYo0AAAAIABCjQAAABggAINAAAAGKBAAwAAAAYo0AAAAIABCjQAAABggAINAAAAGKBAAwAAAAYo\
# 0AAAAIABCjQABFlmZqYOHjyo9957L3DszJkz2rhx40V5vZdeekkHDx6Uw+GQ1+vVI488IkmaM2eO\
# Dh482O3n+eijj5Sdna1Vq1Z1OP7AAw/oiiuuUHZ2tk6ePClJ8vv9uuuuuzRkyBDl5eWpvb09eDcE\
# AL0cBRoALsCPf/xjORwOORwObdmypcM5m82mw4cPa9GiRfL7/ZKkX/ziF9q3b58k6brrrtPEiRM7\
# /HrooYcC17tcLqWmpnYac+5XamqqXC5XYPzZs2e1du1aSdKGDRs0fPhwSdKePXvUt29fHT9+XMeP\
# H5fP5/vWe1qxYoViYmI6HKupqdHGjRt19OhRpaenB3Ju3rxZR44cUVNTk/r06aOnnnrqAmYRAEJT\
# X6sDAECoqa+v16hRozRq1ChJUnl5uX77298Gzv/3f/+3Fi1apPr6er3++uvavn27/vjHP2r58uWS\
# pJ07d573NV5//XUlJSV94+vPnz9f0p8L7pNPPimbzaa6ujo999xzkqSEhASdPHlS8+bNU0NDg2Ji\
# YrRmzRplZ2d/42s+++yzWrZsWYdj27Zt02233aYBAwbIZrNp27ZtkqStW7fq7//+79WvXz/5/X5t\
# 27ZNP/vZz857XwAQDliBBgBDSUlJGjZsmNrb29Xe3q6ZM2fqtddeC/yaPHmy/vCHP+jzzz9Xdna2\
# RowYoeeee04333yzdu/e3e3XWbVqlcaPHy+73S673a5x48ZpzZo1HcZMmjRJ7777riZPnqx+/fop\
# Ly9P27ZtU2Njo2bNmqU333xTt9xyix577LEO5dnlcqmwsPC8GQ4ePKirr75ajY2NGj9+vI4dO9bh\
# +Pvvv6/p06cbbRUBgFBHgQaACzB+/Hg5nU45nU4NHz5cp0+fDmyVuPzyy3XixAlJ0pVXXqnFixer\
# pKREV111ld57770O2zGGDh2qxMRETZw4UVVVVR1eo7m5WUuWLFFVVZWqqqp03333yev1dhjT1NSk\
# goICpaSk6JprrtHf/M3f6Pbbb9f69etVV1cnSfrkk0+UnJzc4brRo0drxIgR573PL774QoMGDdLG\
# jRs1e/Zs/d///V+H4+Xl5crPz9cXX3xxwXMJAKGGLRwAcAGeeeYZffjhh5KkBx98UP/5n/+pF154\
# Qddee60GDhyo48ePa/z48ZKkiooK/fznP9cTTzyhwsJC3XvvvYHn+dnPfiaXy6UZM2ZcUI4zZ85o\
# 7ty5+u53v6sNGzYoPz9f06ZN08yZM+Xz+XT69GkdPnw4sC/6nHXr1nXr+S+55BL5fD716dNHAwcO\
# DOzpvuSSS3Tq1CmNGDFCf/rTn3TJJZdcUH4ACEUUaAC4AOfetHdOXl6ePv74Y5WWl

# %% [markdown]
# ## 図4.5 無作為抽出で得た標本データのヒストグラム

# %%
np.random.seed(0)
sample = np.random.choice(scores, 10000)
num_frame = 50
space = np.logspace(1, 4, num_frame).astype(int)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
def animate(nframe):
    num_sample = space[nframe]
    ax.clear()
    ax.hist(sample[:num_sample], bins=100, range=(0, 100), density=True)
    ax.set_xlabel('点数', fontsize=12)
    ax.set_ylabel('相対度数', fontsize=12)
    ax.set_title(f'サンプルサイズ：{num_sample}')
    ax.set_xlim(20, 100)
    
anim = ani.FuncAnimation(fig, animate, frames=num_frame)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgac24dae6ef4f4d0ca8f873a4635a3867">
#     <br>
#     <input id="_anim_sliderac24dae6ef4f4d0ca8f873a4635a3867" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animac24dae6ef4f4d0ca8f873a4635a3867.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animac24dae6ef4f4d0ca8f873a4635a3867.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animac24dae6ef4f4d0ca8f873a4635a3867.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animac24dae6ef4f4d0ca8f873a4635a3867.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animac24dae6ef4f4d0ca8f873a4635a3867.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animac24dae6ef4f4d0ca8f873a4635a3867.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animac24dae6ef4f4d0ca8f873a4635a3867.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animac24dae6ef4f4d0ca8f873a4635a3867.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animac24dae6ef4f4d0ca8f873a4635a3867.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animac24dae6ef4f4d0ca8f873a4635a3867.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectac24dae6ef4f4d0ca8f873a4635a3867" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgac24dae6ef4f4d0ca8f873a4635a3867";
#     var slider_id = "_anim_sliderac24dae6ef4f4d0ca8f873a4635a3867";
#     var loop_select_id = "_anim_loop_selectac24dae6ef4f4d0ca8f873a4635a3867";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3Xt8U3We//F3KLS4pVQkyE1uUopg\
# sfRG05morX0IznqBzA4DIiMFpLMOjiuPhV2pP1nWVWBn0GEdGWxk1wswgNgyM6Byp5QqRVrAokUX\
# EBAo2BZtgC4Nt/z+QPsQGwpfpEmavJ6Phw+anu85+ZxPT8rbL9/kWDwej0cAAAAArkoLfxcAAAAA\
# NCcEaAAAAMAAARoAAAAwQIAGAAAADBCgAQAAAAMEaAAAAMAAARoAAAAwQIAGAAAADBCgAQAAAAME\
# aAAAAMAAARoAAAAwQIAGAAAADBCgAQAAAAMEaAAAAMAAARoAAAAwQIAGAAAADBCgAQAAAAMEaAAA\
# AMAAARoAAAAwQIAGAAAADBCgAQAAAAMEaAAAAMAAARoAAAAwQIAGAAAADBCgAQAAAAMEaAAAAMAA\
# ARoAAAAwQIAGAAAADBCgAQAAAAMEaAAAAMAAARoAAAAwQIAGAAAADBCgAQAAAAMEaADwkXXr1umh\
# hx5SaWmpv0sBAPwIBGgA8JElS5bI6XTq9ddf93cpcrlcxvtUVVVp2bJl1/ycBw8e1AMPPKCnnnrq\
# ku/PmzdPHTt21O233649e/Zc8/EBwFcI0ABCzuTJk/Xqq6/WP541a5aef/55r2O3bNmiU6dOXfNz\
# nT9/XmfOnNHp06dltVq1efNmde3a9ZIxH330kerq6nTs2DE98sgj17V+bxYuXKh77rlHFy5cuKr6\
# z549q8LCQuXk5GjevHnauHHjVT/X982dO1ctW7a85HuVlZV6/vnnVV5erqysLE2ZMuWajg0AvkSA\
# BoBGzJs3T7GxsVq7dm2DbWfOnLnk8YEDB9S5c2d17dpVt9xyi7p166Y+ffpowIAB6tWrly5cuKBO\
# nTo1CImPPPKIKisrVVdXp61btzbp+bz//vvKycnRkiVL1KJFw78Cxo4dq86dO6tTp07q3LmzevTo\
# oc6dO+vNN99UZGSkXnzxRSUlJV3Tc//ud7/TsGHDLvleQUGBMjMz1b59e7ndbhUVFcnj8VzT8QHA\
# V1peeQgABIesrCxJUklJiaKiolRcXCxJ2rVrlzwej/bu3StJeuWVV9SmTRtJ0ltvvaXFixdr9OjR\
# +vTTT2W1WuuPN2XKFKWnp8vhcEiSevbsqaNHj172uTt16qQ777yzwbZz586pVatWcrvd173+73v9\
# 9deVk5OjjRs3qk+fPl6fw9vykrFjx2rAgAENll78UFFRkSIiIpSSktLouO87ePCgevfurbq6OoWH\
# h6tdu3Y6fvz4JX0GgEBDgAYQMh577DFJktvt1i233KKhQ4dKkt588021bNmyfvlE69atL9nv4Ycf\
# 1oMPPnhJKC0rK9Pf/vY3vfDCC1d83gsXLui999677PKE2tpatWnTxmuAPn/+vMLCwn5U/TU1Nfqn\
# f/onbdy4Ub1799Ztt912xZq/s3//fq1atUovv/zyFcf+v//3/2S1WvXOO+9c9fFPnz6tNm3aKD8/\
# Xw8//LAWLFig06dPX/X+AOAPLOEAEDLsdrvsdru6du2q3r171z9u166d7rjjjvrHP1ynK+mS8FxT\
# U6ORI0dqxowZXmd6f2jx4sXq3r27br/99gbbzp07p9OnTysqKqrBtv/7v/9Tenq6vvrqq2uqv66u\
# Tv/1X/+lhIQExcXF6Y033rjaVkmSPB6PJk6cqFmzZnmt74eWLVsmp9Np9Bw33HCDzp8/r+rqanXr\
# 1k21tbW64YYbjI4BAL5GgAYQ8vbs2aNbb731qsZWVlZq8ODBGjlypB5++OErjj9+/LgmTZp02Tf5\
# bd++XX379vW6bezYsbrlllvUsWPHRp/jcvWvWLFCn3zyiQoLCzVlyhSva54b8x//8

# %% [markdown]
# ## 図4.6 標本平均の分布

# %%
np.random.seed(0)
sample_means = [np.random.choice(scores, 20).mean() for _ in range(10000)]

num_frame = 50
space = np.logspace(1, 4, num_frame).astype(int)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

def animate(nframe):
    num_trial = space[nframe]
    ax.clear()
    prob, _, _ = ax.hist(sample_means[:num_trial],
                         bins=100, range=(0, 100), density=True)
    ax.vlines(np.mean(scores), 0, 1, 'gray')
    ax.set_title(f'試行回数：{num_trial}')
    ax.set_xlabel('点数', fontsize=12)
    ax.set_ylabel('相対度数', fontsize=12)
    ax.set_xlim(50, 90)
    ax.set_ylim(0, prob.max() * 1.1)
    
anim = ani.FuncAnimation(fig, animate, frames=num_frame)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgd8abd054f0ab43858852a0059dfc4da1">
#     <br>
#     <input id="_anim_sliderd8abd054f0ab43858852a0059dfc4da1" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animd8abd054f0ab43858852a0059dfc4da1.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animd8abd054f0ab43858852a0059dfc4da1.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animd8abd054f0ab43858852a0059dfc4da1.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animd8abd054f0ab43858852a0059dfc4da1.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animd8abd054f0ab43858852a0059dfc4da1.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animd8abd054f0ab43858852a0059dfc4da1.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animd8abd054f0ab43858852a0059dfc4da1.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animd8abd054f0ab43858852a0059dfc4da1.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animd8abd054f0ab43858852a0059dfc4da1.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animd8abd054f0ab43858852a0059dfc4da1.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectd8abd054f0ab43858852a0059dfc4da1" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd8abd054f0ab43858852a0059dfc4da1";
#     var slider_id = "_anim_sliderd8abd054f0ab43858852a0059dfc4da1";
#     var loop_select_id = "_anim_loop_selectd8abd054f0ab43858852a0059dfc4da1";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X