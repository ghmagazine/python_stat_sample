# %% [markdown]
# # 独立同一分布

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as ani
from IPython.display import HTML
from scipy import stats

np.random.seed(0)
# %precision 3
# %matplotlib inline

# %% [markdown]
# ## 図9.6 中心極限定理

# %%
def animate(nframe):
    num_trial = space[nframe]
    ax.clear()
    
    ax.hist(sample_mean[:num_trial], bins=100, density=True,
            alpha=0.5, label='10000個のPoi(3)の標本平均')
    ax.plot(xs, rv_true.pdf(xs), label='N(3, 3/10000)', color='gray')
    ax.set_title(f'試行回数：{num_trial}')
    ax.set_xlim(rv_true.isf(0.999), rv_true.isf(0.001))
    ax.set_ylim(0, 25)

l = 3
rv = stats.poisson(l)
n = 10000
sample_size = 10000
Xs_sample = rv.rvs((n, sample_size))
sample_mean = np.mean(Xs_sample, axis=0)
rv_true = stats.norm(l, np.sqrt(l/n))
xs = np.linspace(rv_true.isf(0.999), rv_true.isf(0.001), 100)
num_frame = 50
space = np.logspace(1, 4, num_frame).astype(int)
    
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
anim = ani.FuncAnimation(fig, animate, frames=num_frame)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgbd67b4650f63469a9b832c289ca61863">
#     <br>
#     <input id="_anim_sliderbd67b4650f63469a9b832c289ca61863" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animbd67b4650f63469a9b832c289ca61863.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animbd67b4650f63469a9b832c289ca61863.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animbd67b4650f63469a9b832c289ca61863.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animbd67b4650f63469a9b832c289ca61863.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animbd67b4650f63469a9b832c289ca61863.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animbd67b4650f63469a9b832c289ca61863.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animbd67b4650f63469a9b832c289ca61863.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animbd67b4650f63469a9b832c289ca61863.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animbd67b4650f63469a9b832c289ca61863.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animbd67b4650f63469a9b832c289ca61863.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectbd67b4650f63469a9b832c289ca61863" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgbd67b4650f63469a9b832c289ca61863";
#     var slider_id = "_anim_sliderbd67b4650f63469a9b832c289ca61863";
#     var loop_select_id = "_anim_loop_selectbd67b4650f63469a9b832c289ca61863";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzs3XlQVXee///XZRFQUUQQBUQFQZHV\
# BVcUXMCNGNulzdI92bpNumZqqqd7eqoy3dM1lZr5Ttf0HzO/mU6lYmLSU9mNicYsRMGVHdyNOxpw\
# QVwwIsh+7/39kZZJJqhcBD53eT6qUkUQznndc66Xl28+9xyL3W63CwAAAEC3eJkOAAAAALgSCjQA\
# AADgAAo0AAAA4AAKNAAAAOAACjQAAADgAAo0AAAA4AAKNAAAAOAACjQAAADgAAo0AAAA4AAKNAAA\
# AOAACjQAAADgAAo0AAAA4AAKNAAAAOAACjQAAADgAAo0AAAA4AAKNAAAAOAACjQAAADgAAo0AAAA\
# 4AAKNAAAAOAACjQAAADgAAo0AAAA4AAKNAAAAOAACjQAAADgAAo0AAAA4AAKNAAAAOAACjQAAADg\
# AAo0AAAA4AAKNAAAAOAACjQAAADgAAo0AAAA4AAKNAAAAOAACjQAAADgAAo0AAAA4AAKNAAAAOAA\
# CjQAAADgAAo0APSytLQ0VVdXq7i4uPNzHR0d+vjjj/tkfx988IGqq6s1c+ZM1dfX649//KMk6amn\
# nlJ1dfVDb7+6ulo5OTn65S9/+b3Pv/LKKwoLC1NCQoLOnj370PsBAFfhYzoAALii559/XkeOHJEk\
# /dM//ZOWL1/e+WcWi0UXL17UL3/5S1VUVMhiseg3v/mNgoKCtGrVKs2dO1cNDQ3f297atWv129/+\
# VpKUmZmpa9euacCAAV3uu62tTSNGjNCePXskSVarVa+++qok6f3339fIkSMlSQcPHpSPj49qa2sl\
# ScOGDZOfn5/Dj/Xll1+Wj8/3f1xcu3ZN//Iv/6ITJ07ojTfe0G9+8xtt3brV4W0DgCuiQAOAgyor\
# KzV69GiNHj1akrRnzx79x3/8R+efnzlzRn/7t3+ryspKbdu2TTt37lRdXZ3+8Ic/SJIKCgoeuI9t\
# 27Zp/Pjx99z/z372M0nSoUOH9PLLL8tisejEiRN66623JEljxozR9evX9dxzz+ncuXMaNGiQXnnl\
# Fc2aNcvhx/vv//7v+vOf/6zDhw93fm7Pnj1auHChhg8frtbWVhUWFsput8tisTi8fQBwNSzhAAAH\
# jR8/XmFhYWppaVFLS4see+wxbd26tfO/6dOnKzc3V7dv39asWbM0atQovfXWW1q6dKnKysq6vZ//\
# /M//VHJysqZNm6Zp06YpKSlJr7zyyve+ZvLkySoqKtL06dPl6+ur5cuXKy8vTzU1NXriiSf05Zdf\
# KicnR//1X/91z/JcWFioiooKh45BdXW1YmJi1NLSogEDBmjYsGGqq6tzaBsA4KqYQANADyQnJ3dO\
# oEeOHKmbN2+qra1NkhQcHKyrV68qLCxMI0aM0IsvvqgNGzYoIiJCxcXFev755zu3c/nyZQ0ePFhD\
# hw7V66+/rmnTpnX+2a1bt/SP//iPeuyxxyRJf/7znzuXY9x17do1/fVf/7Wys7MVGxuriRMnat26\
# dbLZbOro6JAknTp1SnFxcfd8LL/73e8UEhKizZs3d/vxNzc3a/Dgwfr444/1+OOP66233lJzc3O3\
# vx8AXBkFGgB64I033vjeGuhdu3bp3Xff1Zw5czRw4EDV1tYqOTlZkrR371796le/0p/+9Cc9/fTT\
# +ru/+7vO7fzyl79UZmamVq5c2aMcHR0devbZZ5WQkKD3339fP/rRj7R48WI99thjam1t1c2bN3Xx\
# 4sXOddFd+fDDD+Xt7e3QfgMCAmS1WnXjxg2NHj1ad+7cUUBAQI8eAwC4Ggo0APTA3Tft3bV8+XId\
# P35cf/7zn/XWW2/pyJEjys7O1tGjR/Xzn/+8xwX5QS5evKh//dd/1dWrV2W1WpWen

# %% [markdown]
# ## 図9.7 大数の法則

# %%
def animate(nframe):
    ax.clear()    
    for pl, ls in zip(plot_list, linestyles):
        ax.plot(space[:nframe+1], pl[:nframe+1], ls=ls, color='gray')
    ax.hlines(p, -1, n, 'k')
    ax.set_xlabel('サンプルサイズ')
    ax.set_ylabel('標本平均')

p = 1/6
rv = stats.bernoulli(p)
n = int(1e5)
sample = rv.rvs((n, 4))
space = np.linspace(100, n, 50).astype(int)
plot_list = np.array([np.mean(sample[:sp], axis=0) for sp in space]).T
linestyles = ['-', '--', ':', '-.']
    
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
anim = ani.FuncAnimation(fig, animate, frames=num_frame-1)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img4740ce19031145fab110b027c5b145e0">
#     <br>
#     <input id="_anim_slider4740ce19031145fab110b027c5b145e0" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim4740ce19031145fab110b027c5b145e0.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim4740ce19031145fab110b027c5b145e0.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim4740ce19031145fab110b027c5b145e0.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim4740ce19031145fab110b027c5b145e0.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim4740ce19031145fab110b027c5b145e0.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim4740ce19031145fab110b027c5b145e0.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim4740ce19031145fab110b027c5b145e0.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim4740ce19031145fab110b027c5b145e0.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim4740ce19031145fab110b027c5b145e0.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim4740ce19031145fab110b027c5b145e0.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select4740ce19031145fab110b027c5b145e0" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4740ce19031145fab110b027c5b145e0";
#     var slider_id = "_anim_slider4740ce19031145fab110b027c5b145e0";
#     var loop_select_id = "_anim_loop_select4740ce19031145fab110b027c5b145e0";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X901fV9+PHXRWytUaM0rMdgJQwr\
# FenU/CABQwHxoG1djW60HudEOxOn89e60+lopdazMj06D2esraY580ddrRaOWnWrnasGFQMmgqg4\
# tbFpEYoIklSQRMDP94+e5nyB2PJWyL3ePB7/mHvv5977unkd8Hk+50OSy7IsCwAAYI8My/cAAADw\
# YSKgAQAggYAGAIAEAhoAABIIaAAASCCgAQAggYAGAIAEAhoAABIIaAAASCCgAQAggYAGAIAEAhoA\
# ABIIaAAASCCgAQAggYAGAIAEAhoAABIIaAAASCCgAQAggYAGAIAEAhoAABIIaAAASCCgAQAggYAG\
# AIAEAhoAABIIaAAASCCgAQAggYAGAIAEAhoAABIIaAAASCCgAQAggYAGAIAEAhoAABIIaAAASCCg\
# AQAggYAGAIAEAhoAABIIaAAASCCgAQAggYAGAIAEAhoAABIIaAAASCCgAQAggYAGAIAEAhoAABII\
# aAAASCCgAQAggYAGAIAEAhoAABIIaAAASCCgAQAggYAGAIAEw/M9wFBRVlYWFRUV+/Q93nnnnfjI\
# Rz6yT9+DdPZSeOykMNlL4bGTwjQYe+nq6ooNGzbs0/f4MBPQg6SioiLa29v36Xt0dXXt80gnnb0U\
# HjspTPZSeOykMA3GXqqrq/fp63/YuYQDAAASCGgAAEggoAEAIIGABgCABAIaAAASCGgAAEggoAEA\
# IIGABgCABAIaAAASDPmAzrIsGhsbo7KyMubOnfuex82fPz/Gjh3bf/vNN9+MP//zP48pU6bEX/7l\
# X8bWrVsHY1wAAPJsyAd0W1tb9Pb2Rnt7ezQ3N8fatWsHPK6ioiLKysr6b991113xhS98IR5//PE4\
# 6KCD4oUXXhiskQEAyKMhH9AdHR0xffr0WLlyZdTX18fy5csHPK6hoSFyuVz/7U996lNx6aWXxtFH\
# Hx2bN2/2O+MBAIaIIR/QPT09UVZWFuvXr49p06ZFT0/PHj3vU5/6VDz22GPx8ssvx8iRI+ORRx7Z\
# x5MCAFAIhud7gHwrLS2Nvr6+GD9+fHR0dMSYMWP26Hlz5syJ733vexER8cUvfjGefPLJOPnkk3c6\
# prm5OZqbmyMiYt26ddHV1bVXZ9/Vxo0b9+nr8/7YS+Gxk8JkL4XHTgqTveTfkA/oqqqqWLRoUcya\
# NSsWL14cs2fP3uPnLlmyJD7/+c/HU089FUcfffRujzc1NUVTU1NERFRXV0dFRcXeGvs9DcZ7kM5e\
# Co+dFCZ7KTx2UpjsJb+G/CUcdXV10d3dHbW1tVFTUxPl5eV79Lxrrrkmvv3tb8fkyZNj9erV8eUv\
# f3kfTwoAQCEY8megc7lctLS09N9ubW2NGTNmRGdnZ4wePXqnY9va2vq/HjduXDz55JODNicAAIVh\
# yJ+B3lV1dXWsWLFij89EAwAwtAz5M9C7KikpiQkTJuR7DAAACpQz0AAAkEBAAwBAAgENAAAJBDQA\
# ACQQ0AAAkEBAAwBAAgENAAAJBDQAACQQ0AAAkEBAAwBAAgENAAAJBDQAACQQ0AAAkEBAAwBAAgEN\
# AAAJBDQAACQQ0AAAkEBAAwBAAgENAAAJBDQAACQQ0AAAkEBAAwBAAgENAAAJBDQAACQQ0AAAkEBA\
# AwBAAgENAAAJBDQAACQQ0AAAkEBAAwBAAgENAAAJBDQAACQQ0AAAkEBAAwBAAgENAAAJBDQAACQQ\
# 0AAAkEBAAwBAAgENAAAJBDQAACQQ0AAAkEBAAwBAAgENAAAJBDQAACQQ0AAAkEBAAwBAAgENAAAJ\
# BDQAACQQ0AAAkGDIB3SWZdHY2BiVlZUxd+7c9zxu/vz5MXbs2P7b8+bNi/r6+qivr
