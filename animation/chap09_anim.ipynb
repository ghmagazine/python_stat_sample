# %% [markdown]
# # 独立同一分布

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as ani
from IPython.display import HTML
from scipy import stats

np.random.seed(0)
# %precision 3
# %matplotlib inline

# %% [markdown]
# ## 図9.6 中心極限定理

# %%
def animate(nframe):
    num_trial = space[nframe]
    ax.clear()
    
    ax.hist(sample_mean[:num_trial], bins=100, density=True,
            alpha=0.5, label='10000個のPoi(3)の標本平均')
    ax.plot(xs, rv_true.pdf(xs), label='N(3, 3/10000)', color='gray')
    ax.set_title(f'試行回数：{num_trial}')
    ax.set_xlim(rv_true.isf(0.999), rv_true.isf(0.001))
    ax.set_ylim(0, 25)

l = 3
rv = stats.poisson(l)
n = 10000
sample_size = 10000
Xs_sample = rv.rvs((n, sample_size))
sample_mean = np.mean(Xs_sample, axis=0)
rv_true = stats.norm(l, np.sqrt(l/n))
xs = np.linspace(rv_true.isf(0.999), rv_true.isf(0.001), 100)
num_frame = 50
space = np.logspace(1, 4, num_frame).astype(int)
    
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
anim = ani.FuncAnimation(fig, animate, frames=num_frame)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img44567834835243d1abd5efbc4198aa1b">
#     <br>
#     <input id="_anim_slider44567834835243d1abd5efbc4198aa1b" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim44567834835243d1abd5efbc4198aa1b.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim44567834835243d1abd5efbc4198aa1b.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim44567834835243d1abd5efbc4198aa1b.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim44567834835243d1abd5efbc4198aa1b.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim44567834835243d1abd5efbc4198aa1b.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim44567834835243d1abd5efbc4198aa1b.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim44567834835243d1abd5efbc4198aa1b.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim44567834835243d1abd5efbc4198aa1b.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim44567834835243d1abd5efbc4198aa1b.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim44567834835243d1abd5efbc4198aa1b.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select44567834835243d1abd5efbc4198aa1b" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img44567834835243d1abd5efbc4198aa1b";
#     var slider_id = "_anim_slider44567834835243d1abd5efbc4198aa1b";
#     var loop_select_id = "_anim_loop_select44567834835243d1abd5efbc4198aa1b";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzs3XlQlWee/v/rsKPigiAKiIZNERFc\
# cEUBFdyISUftJKZ7snWbdM3UVE/39FRluqdrKjVL1/QfM9+ZTqViYtK/Mqsx0ZiFKCgq++IedzTg\
# gjsRQZYDh/P7Iy2TTFA5CNxneb+qUkUUn+c6z8HD5Yf73I/FbrfbBQAAAKBHvEwHAAAAAFwJBRoA\
# AABwAAUaAAAAcAAFGgAAAHAABRoAAABwAAUaAAAAcAAFGgAAAHAABRoAAABwAAUaAAAAcAAFGgAA\
# AHAABRoAAABwAAUaAAAAcAAFGgAAAHAABRoAAABwAAUaAAAAcAAFGgAAAHAABRoAAABwAAUaAAAA\
# cAAFGgAAAHAABRoAAABwAAUaAAAAcAAFGgAAAHAABRoAAABwAAUaAAAAcAAFGgAAAHAABRoAAABw\
# AAUaAAAAcAAFGgAAAHAABRoAAABwAAUaAAAAcAAFGgAAAHAABRoAAABwAAUaAAAAcAAFGgAAAHAA\
# BRoAAABwAAUaAPpYamqqamtrVVJS0vVrHR0d+vjjj/vlfB988IFqa2s1e/ZsNTQ06I9//KMk6emn\
# n1Ztbe0DH7+2tlY5OTn65S9/+b1ff/XVVxUWFqbExESdPn36gc8DAK7Cx3QAAHBFL7zwgg4dOiRJ\
# +qd/+ietWLGi6/csFovOnz+vX/7yl6qsrJTFYtFvfvMbDR8+XI899pjmz5+vxsbG7x1vzZo1+u1v\
# fytJysjI0NWrV+Xn59ftua1Wq0aNGqXdu3dLkmw2m1577TVJ0vvvv6/Ro0dLkvbv3y8fHx9dvnxZ\
# kjRixAj5+/s7/FhfeeUV+fh8/9vF1atX9S//8i86duyY3nzzTf3mN7/R1q1bHT42ALgiCjQAOKi6\
# ulpjx47V2LFjJUm7d+/Wf/7nf3b9/qlTp/S3f/u3qq6u1rZt27Rz507duHFDf/jDHyRJhYWF9z3H\
# tm3bFBsbe9fz/+xnP5MkHThwQK+88oosFouOHTumjRs3SpLGjRuna9eu6fnnn9eZM2c0ePBgvfrq\
# q5ozZ47Dj/c//uM/9Oc//1kHDx7s+rXdu3dr0aJFGjlypNra2lRUVCS73S6LxeLw8QHA1bCEAwAc\
# FBsbq7CwMLW2tqq1tVVPPPGEtm7d2vXfzJkzlZubq1u3bmnOnDkaM2aMNm7cqGXLlqm8vLzH5/mv\
# //ovTZkyRTNmzNCMGTOUlJSkV1999XufM3XqVBUXF2vmzJny9fXVihUrlJeXp7q6Oq1du1Zffvml\
# cnJy9N///d93Lc9FRUWqrKx06BrU1tYqJiZGra2t8vPz04gRI3Tjxg2HjgEArooJNAD0wpQpU7om\
# 0KNHj1Z9fb2sVqskKTg4WFeuXFFYWJhGjRqll156SevXr1dERIRKSkr0wgsvdB3n4sWLGjJkiIYN\
# G6Y33nhDM2bM6Pq9mzdv6h//8R/1xBNPSJL+/Oc/dy3HuOPq1av667/+a2VnZysuLk4TJ07U448/\
# rs7OTnV0dEiSTpw4ofj4+Ls+lt/97ncKCQnR5s2be/z4W1paNGTIEH388cd68skntXHjRrW0tPT4\
# zwOAK6NAA0AvvPnmm99bA71r1y69++67mjdvngYNGqTLly9rypQpkqQ9e/boV7/6lf70pz/pmWee\
# 0d/93d91HeeXv/ylMjIy9Oijj/YqR0dHh5577jklJibq/fff149+9CMtWbJETzzxhNra2lRfX6/z\
# 5893rYvuzocffihvb2+HzhsYGCibzabr169r7Nixun37tgIDA3v1GADA1VCgAaAX7rxp744VK1bo\
# 6NGj+vOf/6yNGzfq0KFDys7O1uHDh/Xzn/+81wX5fs6fP69//dd/1ZUrV2Sz2ZSWl

# %% [markdown]
# ## 図9.7 大数の法則

# %%
def animate(nframe):
    ax.clear()    
    for pl, ls in zip(plot_list, linestyles):
        ax.plot(space[:nframe+1], pl[:nframe+1], ls=ls, color='gray')
    ax.hlines(p, -1, n, 'k')
    ax.set_xlabel('サンプルサイズ')
    ax.set_ylabel('標本平均')

p = 1/6
rv = stats.bernoulli(p)
n = int(1e5)
sample = rv.rvs((n, 4))
space = np.linspace(100, n, 50).astype(int)
plot_list = np.array([np.mean(sample[:sp], axis=0) for sp in space]).T
linestyles = ['-', '--', ':', '-.']
    
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
anim = ani.FuncAnimation(fig, animate, frames=num_frame-1)
js_anim = HTML(anim.to_jshtml())
plt.close()

js_anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgb029d3893431466e81f206733474f355">
#     <br>
#     <input id="_anim_sliderb029d3893431466e81f206733474f355" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animb029d3893431466e81f206733474f355.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animb029d3893431466e81f206733474f355.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animb029d3893431466e81f206733474f355.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animb029d3893431466e81f206733474f355.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animb029d3893431466e81f206733474f355.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animb029d3893431466e81f206733474f355.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animb029d3893431466e81f206733474f355.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animb029d3893431466e81f206733474f355.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animb029d3893431466e81f206733474f355.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animb029d3893431466e81f206733474f355.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectb029d3893431466e81f206733474f355" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb029d3893431466e81f206733474f355";
#     var slider_id = "_anim_sliderb029d3893431466e81f206733474f355";
#     var loop_select_id = "_anim_loop_selectb029d3893431466e81f206733474f355";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3